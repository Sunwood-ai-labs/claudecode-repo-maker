# %% [markdown]
# # サンプルJupyter Notebook
#
# これは**Jupyter Notebook Preview App**のテスト用サンプルです。

# %%
print('Hello, Jupyter Notebook!')
# Out:
# Hello, Jupyter Notebook!

# %% [markdown]
# ## データ処理の例
#
# 簡単なデータ処理の例を示します。

# %%
# 数値のリストを作成
numbers = [1, 2, 3, 4, 5]

# 各要素を2乗
squares = [n**2 for n in numbers]
squares
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## 機能一覧
#
# このアプリでは以下の機能が利用できます：
#
# 1. GitHubリポジトリからNotebookを取得
# 2. ローカルファイルのアップロード
# 3. マークダウンのレンダリング
# 4. コードのシンタックスハイライト
# 5. 出力の表示（テキスト、画像など）

# %%
def setup_complete():
    print('セットアップ完了！')
    print('アプリを起動してください: python server.py')

setup_complete()
# Out:
# セットアップ完了！
# アプリを起動してください: python server.py
